# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
a = np.array([1,2,3,4,5])
a
plt.plot(a)
plt.show()

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints,ypoints, 'o')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints,marker = 'o')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints,marker = '*')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, 'o:r')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, 'o--r')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, 'o-.r')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, 'o:b')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, 'o:g')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, marker = 'o', ms = 25)
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, marker = 'o', ms = 25, mec = 'r')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([1,2,3,4])
plt.plot(xpoints,ypoints, marker = 'o', ms = 25, mfc = 'y', mec = 'r')
plt.show() # mec marker edge colour, mfc marker face colour, ms marker size

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()
